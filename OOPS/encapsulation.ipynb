# %%
class Bank:
    def __init__(self, username, balance, password):
        self.username = username
        self.balance = username
        self.password = password

u1 = Bank("Charan", 5000, "Charan@123")
u1.balance = 10000
print(u1.balance)
# Out:
# 10000

# %%
class Bank:
    def __init__(self, username, balance, password):
        self.username = username
        self._balance = balance
        self.__password = password

    def withdraw(self, amount):
        if self._balance >= amount:
            self._balance -= amount
            return f"Withdraw Successfull and current balance is{self._balance} "
        return "Insufficinet Balance"
            
    def __totalusers(self):
        return "Total users are 100"
    
u1 = Bank("Charan", 5000, "Charan@123")
print(u1._balance) # protected members access - obj._member_Name
# private members access: name magling - obj._className__memberName
print(u1._Bank__totalusers())
# Out:
# 5000
# Total users are 100
