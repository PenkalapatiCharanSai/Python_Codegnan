# %%
n = int(input("Enter a number"))
if n % 2 == 0:
    if n >= 0:
        print("+ve even")
    else:
        print("-ve even")
else:
    if n >= 0:
        print("+ve odd")
    else:
        print("-ve odd")
# Out:
# Enter a number 15
# +ve odd
