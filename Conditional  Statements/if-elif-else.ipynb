# %%
marks = int(input("Enter a marks:"))
if 90 <= marks <= 100:
    print("Grade A")
elif 80 <= marks <= 89:
    print("Grade B")
elif 60 <= marks <= 79:
    print("Grade C")
elif 40 <= marks <= 59:
    print("Grade D")
elif marks < 0 or marks >100:
    print("Invalid Input")
else:
    print("Fail")
# Out:
# Enter a marks: 90
# Grade A

# %%
marks = int(input("Enter marks: "))
if marks < 0 or marks > 100:
    print("Invalid Input")
elif marks >= 90:
    print("Grade A")
elif marks >= 80:
    print("Grade B")
elif marks >= 60:
    print("Grade C")
elif marks >= 40:
    print("Grade D")
else:
    print("Fail")
# Out:
# Enter marks:  90
# Grade A

# %%
num = int(input("Enter a number:"))
if num % 2 == 0 and num >= 0:
    print("Positive even")
elif num % 2 == 0 and num < 0:
    print("Negative even")
elif num % 2 == 1 and num > 0:
    print("Positive odd")
elif num % 2 > 0 and num < 0:
    print("Negative odd")
else:
    print("Invalid input")
# Out:
# Enter a number: 8
# Positive even

# %%
num = int(input("Enter a number: "))
print("Zero (even)" if num == 0 else ("Positive" if num > 0 else "Negative") + " " + ("even" if num % 2 == 0 else "odd"))
# Out:
# Enter a number:  -10
# Negative even

# %%
n = int(input())
if n >- 1 and n % 2 == 0:
    print("+ve even")
elif n < 0 and n % 2 == 0:
    print("-ve even")
elif n >- 1 and n % 2 == 1:
    print("+ve odd")
else:
    print("-ve odd")
# Out:
#  -15
# -ve odd
