# %%
n = 0
if n == 0:
    print("zero")
else:
    print("non zero")
# Out:
# zero

# %%
num = int(input())

if num > 0:
    print("positive number")
elif num < 0:
    print("negative number")
else:
    print("zero")
# Out:
#  -5
# negative number

# %%
num = int(input())

if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
#  9
# Odd

# %%
age = int(input())

if age >= 18:
    print("Eligible to vote")
else:
    print("Not eligible to vote")
# Out:
#  23
# Eligible to vote

# %%
num = int(input())

if num % 3 == 0:
    print("It is divisible by 3")
else:
    print("It is not divisible by 3")
# Out:
#  14
# It is not divisible by 3

# %%
num = int(input())

if num % 3 == 0 and num % 5 == 0:
    print("It is divisible by both 3 and 5")
else:
    print("It is not divisible by both number")
# Out:
#  15
# It is divisible by both 3 and 5

# %%
a  = int(input())
b = int(input())
if a  b:
    print(a," is bigger than ",b)
else:
    print(b,"is bigger than ", a)
# Out:
#  5
#  4
# 4 is bigger than  5
