# %%
# input reading from user
name = input()
print(type(name), name)
# Out:
#  charan
# <class 'str'> charan

# %%
# reading integers from user
n = int(input())
print(type(n), n)
# Out:
#  45
# <class 'int'> 45

# %%
# reading float from user
val = float(input())
print(type(val), val)
# Out:
#  45
# <class 'float'> 45.0

# %%
# Reading complex value from user
x = int(input("Enter x value: "))
y = int(input("Enter y value: "))
c = complex(x,y)
print(type(c), c)
# Out:
# Enter x value:  5
# Enter y value:  9
# <class 'complex'> (5+9j)

# %%
# reading boolean value from user
n = bool(input())
print(type(n), n)
# Out:
#  0
# <class 'bool'> True

# %%
n = bool(int(input()))
print(type(n), n)
# Out:
#  0
# <class 'bool'> False

# %%
print(bool([]))
# Out:
# False

# %%
# One Egg price is 5 rupees and what is price of 'N' eggs price
n = int(input("Enter a number of eggs : "))
p = 5
c = n * p
print("Total cost of eggs:",c)
# Out:
# Enter a number of eggs :  10
# Total cost of eggs: 50

# %%
# If box contains N pencil and total price is M, then what price of each pencil
n = int(input("Enter number of pencils: "))
m = int(input("Enter total price of pencils: "))
pencil = m/n
print("Each pencil cost is:", pencil)
# Out:
# Enter number of pencils:  10
# Enter total price of pencils:  80
# Each pencil cost is: 8.0

# %%
# red ball price is - 25
# green ball price us - 30
# if i buy N-red ball and M-Green balls,than what is the cost.
n = int(input("Enter a red balls: "))
m = int(input("Enter a green balls: "))
red = 25
green = 30
r = red * n
g = green * m
final = r + g
print("Final cost:", final)
# Out:
# Enter a red balls:  10
# Enter a green balls:  5
# Final cost: 400
